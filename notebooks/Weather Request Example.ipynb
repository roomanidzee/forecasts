# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import lya
cfg = lya.AttrDict.from_yaml('config.yml')

# %%
import sys
sys.path.append('..')
from src.client import WeatherAPIClient
from src.db.mappers import map_to_city, map_to_weather_info
from src.db.client import DBClient

# %%
api_client = WeatherAPIClient('http://api.openweathermap.org', cfg['api']['key'])

# %%
response = await api_client.get_weather_info('551487')

# %%
response
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1597503600,
#    'main': {'temp': 285.96,
#     'feels_like': 282.01,
#     'temp_min': 284.71,
#     'temp_max': 285.96,
#     'pressure': 1006,
#     'sea_level': 1007,
#     'grnd_level': 997,
#     'humidity': 88,
#     'temp_kf': 1.25},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 6.06, 'deg': 14},
#    'visibility': 10000,
#    'pop': 0.35,
#    'rain': {'3h': 0.18},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-08-15 15:00:00'},
#   {'dt': 1597514400,
#    'main': {'temp': 285.03,
#     'feels_like': 281.31,
#     'temp_min': 284.44,
#     'temp_max': 285.03,
#     'pressure': 1007,
#     'sea_level': 1008,
#     'grnd_level': 998,
#     'humidity': 90,
#     'temp_kf': 0.59},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
# ...

# %%
city = map_to_city(response)
weather_info = map_to_weather_info(response)

# %%
city
# Out:
# City(name='Kazan’', lat_coord=55.7887, lon_coord=49.1221, country='RU')

# %%
weather_info
# Out:
# [WeatherInfo(city_api_id=551487, dt=1597503600, dt_txt='2020-08-15 15:00:00', temp=14.108888888888888, temp_min=14.039444444444444, temp_max=14.108888888888888, pressure=1006, sea_level=1007, grnd_level=997, humidity=88, wind_speed=6.06, wind_degree=14),
#  WeatherInfo(city_api_id=551487, dt=1597514400, dt_txt='2020-08-15 18:00:00', temp=14.05722222222222, temp_min=14.024444444444445, temp_max=14.05722222222222, pressure=1007, sea_level=1008, grnd_level=998, humidity=90, wind_speed=5.49, wind_degree=8),
#  WeatherInfo(city_api_id=551487, dt=1597525200, dt_txt='2020-08-15 21:00:00', temp=14.026111111111113, temp_min=14.016111111111112, temp_max=14.026111111111113, pressure=1007, sea_level=1007, grnd_level=997, humidity=90, wind_speed=5.26, wind_degree=6),
# ...

# %%
db_url = 'postgresql://forecast_user:forecast_pass@localhost:5432/forecast_db'

# %%
db_client = DBClient(db_url, True)

# %%
await db_client.insert_weather_info(weather_info)

# %%
await db_client.insert_city(city)
# Out:
# 1

# %%
await db_client.select_cities()

# %%
await db_client.select_weather_info()

# %%
response2 = await api_client.get_weather_info('524901')
city2 = map_to_city(response2)
weather_info2 = map_to_weather_info(response2)

# %%
city2
# Out:
# City(name='Moscow', lat_coord=55.7522, lon_coord=37.6156, country='RU')

# %%
await db_client.insert_city(city2)
# Out:
# 2

# %%
await db_client.insert_weather_info(weather_info2)

# %%
response3 = await api_client.get_weather_info('532096')
city3 = map_to_city(response3)
weather_info3 = map_to_weather_info(response3)

# %%
city3
# Out:
# City(name='Makhachkala', lat_coord=42.9764, lon_coord=47.5024, country='RU')

# %%
await db_client.insert_city(city3)
# Out:
# 3

# %%
await db_client.insert_weather_info(weather_info3)
