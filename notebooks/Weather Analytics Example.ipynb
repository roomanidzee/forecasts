# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
db_url = 'postgresql://forecast_user:forecast_pass@localhost:5432/forecast_db'

# %%
engine = create_engine(db_url)

# %%
cities_df = pd.read_sql_query('SELECT * FROM cities', con=engine)

# %%
from IPython.display import display
display(cities_df)
# Out:
#    id         name  lat_coord  lon_coord country
# 0   1       Kazan’    55.7887    49.1221      RU
# 1   2       Moscow    55.7522    37.6156      RU
# 2   3  Makhachkala    42.9764    47.5024      RU

# %%
wi_df = pd.read_sql_query('SELECT * FROM weather_info LIMIT 40', con=engine)

# %%
display(wi_df)
# Out:
#     id  city_api_id          dt               dt_txt       temp   temp_min  \
# 0    1       551487  1597503600  2020-08-15 15:00:00  14.108889  14.039444
# 1    2       551487  1597514400  2020-08-15 18:00:00  14.057222  14.024444
# 2    3       551487  1597525200  2020-08-15 21:00:00  14.026111  14.016111
# 3    4       551487  1597536000  2020-08-16 00:00:00  13.996111  13.994444
# 4    5       551487  1597546800  2020-08-16 03:00:00  13.976667  13.976667
# 5    6       551487  1597557600  2020-08-16 06:00:00  14.033889  14.033889
# 6    7       551487  1597568400  2020-08-16 09:00:00  14.265556  14.265556
# 7    8       551487  1597579200  2020-08-16 12:00:00  14.332222  14.332222
# 8    9       551487  1597590000  2020-08-16 15:00:00  14.280000  14.280000
# 9   10       551487  1597600800  2020-08-16 18:00:00  14.070556  14.070556
# 10  11       551487  1597611600  2020-08-16 21:00:00  14.013333  14.013333
# ...

# %%
display(wi_df[wi_df['wind_speed'] > 5])
# Out:
#     id  city_api_id          dt               dt_txt       temp   temp_min  \
# 0    1       551487  1597503600  2020-08-15 15:00:00  14.108889  14.039444
# 1    2       551487  1597514400  2020-08-15 18:00:00  14.057222  14.024444
# 2    3       551487  1597525200  2020-08-15 21:00:00  14.026111  14.016111
# 3    4       551487  1597536000  2020-08-16 00:00:00  13.996111  13.994444
# 4    5       551487  1597546800  2020-08-16 03:00:00  13.976667  13.976667
# 6    7       551487  1597568400  2020-08-16 09:00:00  14.265556  14.265556
# 16  17       551487  1597676400  2020-08-17 15:00:00  14.232222  14.232222
# 21  22       551487  1597730400  2020-08-18 06:00:00  14.161111  14.161111
# 22  23       551487  1597741200  2020-08-18 09:00:00  14.321111  14.321111
# 23  24       551487  1597752000  2020-08-18 12:00:00  14.327778  14.327778
#
#      temp_max  pressure  sea_level  grnd_level  humidity  wind_speed  \
# 0   14.108889    1006.0     1007.0       997.0        88        6.06
# ...

# %%
display(wi_df[wi_df['wind_speed'] < 5])
# Out:
#     id  city_api_id          dt               dt_txt       temp   temp_min  \
# 5    6       551487  1597557600  2020-08-16 06:00:00  14.033889  14.033889
# 7    8       551487  1597579200  2020-08-16 12:00:00  14.332222  14.332222
# 8    9       551487  1597590000  2020-08-16 15:00:00  14.280000  14.280000
# 9   10       551487  1597600800  2020-08-16 18:00:00  14.070556  14.070556
# 10  11       551487  1597611600  2020-08-16 21:00:00  14.013333  14.013333
# 11  12       551487  1597622400  2020-08-17 00:00:00  13.979444  13.979444
# 12  13       551487  1597633200  2020-08-17 03:00:00  14.029444  14.029444
# 13  14       551487  1597644000  2020-08-17 06:00:00  14.031667  14.031667
# 14  15       551487  1597654800  2020-08-17 09:00:00  14.132778  14.132778
# 15  16       551487  1597665600  2020-08-17 12:00:00  14.306667  14.306667
# 17  18       551487  1597687200  2020-08-17 18:00:00  13.997222  13.997222
# ...

# %%
wi_df_full = pd.read_sql_query('SELECT * FROM weather_info', con=engine)

# %%
wi_df_full.shape
# Out:
# (120, 13)

# %%
wind_ids = wi_df_full.groupby(['city_api_id'])['wind_degree'].transform(max) == wi_df_full['wind_degree']

# %%
wi_df_full[wind_ids]
# Out:
#     id  city_api_id          dt               dt_txt       temp   temp_min  \
# 7    8       551487  1597579200  2020-08-16 12:00:00  14.332222  14.332222
# 57  58       524901  1597687200  2020-08-17 18:00:00  14.484444  14.484444
# 84  85       532096  1597546800  2020-08-16 03:00:00  14.542222  14.542222
#
#      temp_max  pressure  sea_level  grnd_level  humidity  wind_speed  \
# 7   14.332222    1008.0     1008.0       998.0        63        4.66
# 57  14.484444    1010.0     1010.0       994.0        67        2.14
# 84  14.542222    1013.0     1013.0      1013.0        52        2.98
#
#     wind_degree
# 7         357.0
# 57        351.0
# 84        297.0
